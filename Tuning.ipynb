# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
from sklearn.datasets import load_digits

# %%
data = load_digits()

# %%
X_train = data['data']
y_train = data['target']

# %%
tuned_parameters = {'n_estimators':[10,50,100,300]}
scores = ['precision','recall']
rf = RandomForestClassifier()

# %%
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    #y_true, y_pred = y_test, clf.predict(X_test)
    #print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'n_estimators': 100}
#
# Grid scores on development set:
#
# 0.911 (+/-0.053) for {'n_estimators': 10}
# 0.939 (+/-0.045) for {'n_estimators': 50}
# 0.943 (+/-0.030) for {'n_estimators': 100}
# 0.942 (+/-0.035) for {'n_estimators': 300}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'n_estimators': 300}
#
# Grid scores on development set:
#
# 0.898 (+/-0.062) for {'n_estimators': 10}
# 0.930 (+/-0.058) for {'n_estimators': 50}
# 0.933 (+/-0.045) for {'n_estimators': 100}
# 0.939 (+/-0.038) for {'n_estimators': 300}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.

# %%
tuned_parameters = {'n_estimators':[10,50,100,300], 'criterion':['gini','entropy'], 'max_depth':[5,10,15], 'min_samples_split':[2,4,9]}
scores = ['precision','recall']

# %%
# %%time
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    #y_true, y_pred = y_test, clf.predict(X_test)
    #print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 300}
#
# Grid scores on development set:
#
# 0.848 (+/-0.108) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 10}
# 0.901 (+/-0.067) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 50}
# 0.902 (+/-0.057) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
# 0.909 (+/-0.052) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
# 0.852 (+/-0.074) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 10}
# 0.897 (+/-0.051) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.901 (+/-0.057) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.904 (+/-0.051) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 300}
# 0.864 (+/-0.044) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 10}
# 0.898 (+/-0.069) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 50}
# 0.902 (+/-0.047) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 100}
# 0.904 (+/-0.060) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 300}
# 0.900 (+/-0.075) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 10}
# 0.944 (+/-0.042) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 0.940 (+/-0.043) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 0.945 (+/-0.031) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 300}
# 0.906 (+/-0.051) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 10}
# 0.940 (+/-0.038) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.938 (+/-0.049) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.940 (+/-0.035) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 300}
# 0.912 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 10}
# 0.932 (+/-0.032) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 50}
# 0.933 (+/-0.048) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 100}
# 0.938 (+/-0.045) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 300}
# 0.899 (+/-0.038) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 10}
# 0.937 (+/-0.048) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 50}
# 0.945 (+/-0.031) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 0.945 (+/-0.035) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 300}
# 0.905 (+/-0.059) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 10}
# 0.939 (+/-0.028) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 50}
# 0.943 (+/-0.032) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 100}
# 0.942 (+/-0.036) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 300}
# 0.903 (+/-0.030) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 10}
# 0.931 (+/-0.040) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 50}
# 0.935 (+/-0.042) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 100}
# 0.938 (+/-0.034) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 300}
# 0.843 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 10}
# 0.911 (+/-0.045) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 50}
# 0.917 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
# 0.906 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
# 0.857 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 10}
# 0.904 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.911 (+/-0.036) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.914 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 300}
# 0.865 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 10}
# 0.896 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 50}
# 0.906 (+/-0.048) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 100}
# 0.906 (+/-0.053) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 300}
# 0.908 (+/-0.058) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 10}
# 0.940 (+/-0.043) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 0.942 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 0.946 (+/-0.031) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 300}
# 0.913 (+/-0.052) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 10}
# 0.939 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.939 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.942 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 300}
# 0.902 (+/-0.049) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 10}
# 0.933 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 50}
# 0.931 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 100}
# 0.941 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 300}
# 0.901 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 10}
# 0.944 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 50}
# 0.936 (+/-0.048) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 0.945 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 300}
# 0.915 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 10}
# 0.940 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 50}
# 0.945 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 100}
# 0.945 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 300}
# 0.904 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 10}
# 0.937 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 50}
# 0.939 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 100}
# 0.937 (+/-0.033) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 300}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 50}
#
# Grid scores on development set:
#
# 0.865 (+/-0.041) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 10}
# 0.883 (+/-0.067) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 50}
# 0.901 (+/-0.058) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
# 0.899 (+/-0.058) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
# 0.841 (+/-0.059) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 10}
# 0.895 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.902 (+/-0.056) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.901 (+/-0.054) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 300}
# 0.843 (+/-0.090) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 10}
# 0.894 (+/-0.049) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 50}
# 0.904 (+/-0.056) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 100}
# 0.900 (+/-0.060) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 300}
# 0.898 (+/-0.062) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 10}
# 0.932 (+/-0.049) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 0.932 (+/-0.052) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 0.934 (+/-0.053) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 300}
# 0.898 (+/-0.064) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 10}
# 0.927 (+/-0.067) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.933 (+/-0.051) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.938 (+/-0.045) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 300}
# 0.899 (+/-0.043) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 10}
# 0.928 (+/-0.046) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 50}
# 0.932 (+/-0.045) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 100}
# 0.930 (+/-0.048) for {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 300}
# 0.893 (+/-0.085) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 10}
# 0.939 (+/-0.042) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 50}
# 0.939 (+/-0.037) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 0.940 (+/-0.043) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 300}
# 0.898 (+/-0.076) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 10}
# 0.939 (+/-0.037) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 50}
# 0.931 (+/-0.041) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 100}
# 0.937 (+/-0.038) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 300}
# 0.898 (+/-0.052) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 10}
# 0.927 (+/-0.057) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 50}
# 0.926 (+/-0.051) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 100}
# 0.936 (+/-0.042) for {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 300}
# 0.869 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 10}
# 0.896 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 50}
# 0.896 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
# 0.907 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 300}
# 0.866 (+/-0.068) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 10}
# 0.901 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.905 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.903 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 300}
# 0.858 (+/-0.079) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 10}
# 0.896 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 50}
# 0.903 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 100}
# 0.901 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 9, 'n_estimators': 300}
# 0.902 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 10}
# 0.936 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 0.938 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 0.938 (+/-0.045) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 300}
# 0.903 (+/-0.073) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 10}
# 0.940 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.935 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.940 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 300}
# 0.903 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 10}
# 0.926 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 50}
# 0.934 (+/-0.038) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 100}
# 0.934 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 300}
# 0.905 (+/-0.051) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 10}
# 0.938 (+/-0.039) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 50}
# 0.936 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 0.939 (+/-0.048) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 300}
# 0.901 (+/-0.046) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 10}
# 0.942 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 50}
# 0.934 (+/-0.032) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 100}
# 0.939 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 300}
# 0.906 (+/-0.043) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 10}
# 0.932 (+/-0.047) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 50}
# 0.934 (+/-0.052) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 100}
# 0.936 (+/-0.041) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 300}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#
# Wall time: 3min 40s

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# %%time
tuned_parameters = {'n_estimators':[10,50,100,300], 'criterion':['gini','entropy'], 'max_depth':[5,10,15], 'min_samples_split':[2,4,9]}
scores = ['precision','recall']
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = RandomizedSearchCV(RandomForestClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score, n_iter=10)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    #y_true, y_pred = y_test, clf.predict(X_test)
    #print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'gini'}
#
# Grid scores on development set:
#
# 0.939 (+/-0.045) for {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 10, 'criterion': 'entropy'}
# 0.859 (+/-0.063) for {'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'entropy'}
# 0.940 (+/-0.037) for {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'entropy'}
# 0.899 (+/-0.059) for {'n_estimators': 10, 'min_samples_split': 9, 'max_depth': 10, 'criterion': 'entropy'}
# 0.934 (+/-0.039) for {'n_estimators': 50, 'min_samples_split': 4, 'max_depth': 10, 'criterion': 'entropy'}
# 0.900 (+/-0.055) for {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'gini'}
# 0.901 (+/-0.056) for {'n_estimators': 50, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'gini'}
# 0.943 (+/-0.033) for {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'gini'}
# 0.942 (+/-0.030) for {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'entropy'}
# 0.940 (+/-0.034) for {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 10, 'criterion': 'gini'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'n_estimators': 50, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'gini'}
#
# Grid scores on development set:
#
# 0.933 (+/-0.036) for {'n_estimators': 50, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'entropy'}
# 0.929 (+/-0.050) for {'n_estimators': 100, 'min_samples_split': 9, 'max_depth': 10, 'criterion': 'entropy'}
# 0.895 (+/-0.059) for {'n_estimators': 50, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'entropy'}
# 0.938 (+/-0.044) for {'n_estimators': 50, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'entropy'}
# 0.893 (+/-0.046) for {'n_estimators': 50, 'min_samples_split': 9, 'max_depth': 5, 'criterion': 'gini'}
# 0.859 (+/-0.068) for {'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'entropy'}
# 0.904 (+/-0.083) for {'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 10, 'criterion': 'gini'}
# 0.940 (+/-0.043) for {'n_estimators': 50, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'gini'}
# 0.899 (+/-0.058) for {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'gini'}
# 0.905 (+/-0.052) for {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'entropy'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#
# Wall time: 30 s
